# %%
try:
    x = 10 / 2
except :
    print("Divide by zero not possible!")
else:
    print("Division successful!")
#finally:
#    print("by default it will run")
# Out:
# Division successful!

# %%
try:
    value = int(input("Enter a number: "))
    result = 10 / value
except ValueError:
    print("Kindly enter the valid value")
except ZeroDivisionError:
    print("Division by zero is not allowed.")
# Out:
# Enter a number:  hjbhb
# Kindly enter the valid value

# %%
class CustomError(Exception):
    pass
try:
    raise CustomError("Something went wrong!")
except CustomError as e:
    print(e)

# %%
class user_define_error(Exception):
    def __init__(self, value):
        self.value = value
    def __str__(self):
        return(repr(self.value))
try:
    raise user_define_error(3*2)
except user_define_error as e:
    print('My new Exception occurred:', e.value)
# Out:
# My new Exception occurred: 6

# %%
try:
    file = open(r"C:\Users\hp\OneDrive\Desktop\Purchase.csv", "r")
    content = file.read()
    print(content)
except FileNotFoundError:
    print("The file does not exist.")
except PermissionError:
    print("Permission Denied")
finally:
    try:
        file.close()
    except NameError:
        pass
# Out:
# id,purch_date,customer_num,product_num,amount,paid
# 1,2019-01-03,823,27,12,568.92
# 2,2019-01-03,606,28,14,395.36
# 3,2019-01-03,955,9,17,510.17
# 4,2019-01-03,577,19,3,68.49
# 5,2019-01-03,429,8,18,759.42
# 6,2019-01-03,275,36,18,176.76
# 7,2019-01-03,456,21,10,904.8
# 8,2019-01-03,526,58,19,1387.95
# 9,2019-01-03,326,44,2,61.34
# 10,2019-01-03,13,21,5,316.7
# 11,2019-01-03,727,47,20,966.4
# 12,2019-01-03,589,30,20,459.2
# 13,2019-01-03,305,1,19,120.84
# 14,2019-01-03,789,22,5,301.3
# 15,2019-01-03,800,37,14,867.86
# 16,2019-01-03,282,32,6,553.98
# 17,2019-01-03,121,5,5,436.95
# 18,2019-01-03,40,60,1,41.22
# 19,2019-01-03,94,53,18,1319.76
# 20,2019-01-03,450,43,18,732.42
# 21,2019-01-03,897,45,2,91.54
# 22,2019-01-03,737,50,11,682.66
# 23,2019-01-03,890,32,14,1292.62
# 24,2019-01-03,917,37,12,743.88
# 25,2019-01-03,349,22,1,38.57
# 26,2019-01-03,465,18,16,666.88
# 27,2019-01-03,183,12,2,85.12
# 28,2019-01-03,594,22,1,34.35
# 29,2019-01-03,826,26,14,1096.34
# ...

# %%
try:
    with open("C:\Users\hp\OneDrive\Desktop\m.txt", "w") as file:
        file.write("Hello, world!")
except IOError as e:
    print(f"Error writing to file: {e}")

# %%
try:
    with open("C:\Users\hp\OneDrive\Desktop\m.txt", "r") as file:
        for line in file:
            print(line.strip())
except FileNotFoundError:
    print("Could not find the file.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# %%
import logging
logging.basicConfig(filename="error.log",level=logging.ERROR)
try:
    with open(r"C:\Users\hp\OneDrive\Desktop\m.txt", "r") as file:
        content = file.read()
except FileNotFoundError as e:
    logging.error(f"FileNotFoundError: {e}")
except Exception as e:
    logging.error(f"Unexpected error: {e}")

# %%
import csv
try:
    with open("C:\Users\hp\OneDrive\Desktop\Purchase.csv", newline='') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            print(row)
except FileNotFoundError:
    print("CSV file not found.")
except csv.Error as e:
    print(f"CSV parsing error: {e}")

# %%
import json

data = {"Book_Name": "Uncle-Tom", "Author": "Harriet Beecher Stowe"}
try:
    with open("data.json", "w") as file:
        json.dump(data, file)
except IOError as e:
    print(f"Error writing JSON file: {e}")

# %%
import requests

try:
    response = requests.get("https://api.github.com/user", timeout=5)
    response.raise_for_status() 
    print(response.json())
except requests.exceptions.HTTPError as e:
    print(f"HTTP error: {e}")
except requests.exceptions.ConnectionError:
    print("Connection error.")
except requests.exceptions.Timeout:
    print("Request timed out.")
except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")

# %%
import socket
try:
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.settimeout(5)
    s.connect(("example.com", 80))
    s.sendall(b"GET / HTTP/1.1\r\nHost: example.com\r\n\r\n")
    data = s.recv(1024)
    print(data.decode())
except socket.timeout:
    print("Connection timed out.")
except socket.gaierror:
    print("Address-related error (e.g., DNS lookup failure).")
except socket.error as e:
    print(f"Socket error: {e}")
finally:
    s.close()

# %%
import requests
url = "https://www.cloudflare.com/learning/ai/what-is-large-language-model/"
try:
    with requests.get(url, stream=True, timeout=10) as r:
        r.raise_for_status()
        with open("file.zip", "wb") as f:
            for chunk in r.iter_content(chunk_size=8192):
                f.write(chunk)
except requests.exceptions.RequestException as e:
    print(f"Download failed: {e}")

# %%
import logging
import requests
logging.basicConfig(filename="network_errors.log", level=logging.ERROR)
def fetching(url):
    try:
        r = requests.get(url, timeout=3)
        r.raise_for_status()
        return r.text
    except requests.exceptions.RequestException as e:
        logging.error(f"Failed to fetch {url}: {e}")
        return None

data = fetching("https://www.cloudflare.com/learning/ai/what-is-large-language-model/")
if data:
    print(data[:100])

# %%
def divide(a, b):
    print(f"a: {a}, b: {b}")
    return a / b
divide(10, 2)

# %%
import pdb
def divide(a, b):
    pdb.set_trace()
    return a / b

divide(10, 2)

# %%
import logging
logging.basicConfig(level=logging.DEBUG)
def divide(a, b):
    logging.debug(f"a: {a}, b: {b}")
    return a / b

# %%
import unittest
class TestMath(unittest.TestCase):
    def test_divide(self):
        self.assertEqual(divide(10, 2), 5)
if __name__ == "__main__":
    unittest.main()

# %%
x = 10
assert x > 0, "It should be positive"
assert x < 5, "it is greater"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[53], line 3
#       1 x = 10
#       2 assert x > 0, "It should be positive"
# ----> 3 assert x < 5, "it is greater"
#
# AssertionError: it is greater
